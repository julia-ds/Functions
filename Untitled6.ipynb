# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.base import TransformerMixin, BaseEstimator, ClusterMixin
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA

# %%
def plot_bars(groupby_f, cols, df, agg_f):
    fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(16, 8))
    for col, ax in zip(cols, axes.flatten()):
        temp = df.groupby(groupby_f)[col].agg(agg_f).reset_index() 
        sns.barplot(x=groupby_f, y=col, data=temp, ax=ax)
    plt.show();

# %%
df = pd.read_excel('classification_case.xlsx',  sheet_name='classific_data', index_col=0)

# %% [markdown]
# # Exploratory data analysis

# %%
df.head()
# Out:
#            f1            f2        f3          f4          f5  f6  \
# client_id
# 1           8   3557.333333  6.000000   68.489754   79.901296   6
# 2           5  19046.793754  6.666667  103.547196    9.186530   7
# 3           3   1204.780421  0.666667    0.715220    4.637334   5
# 4           3   4413.223754  0.666667   25.565524  100.000000   2
# 5           2   1669.557088  0.333333   21.997435  100.000000   2
#
#                       f7          f8
# client_id
# 1            5959.920000   42.304261
# 2          163662.266667    0.000000
# 3           37436.670000    0.000000
# 4            4410.333333    0.000000
# 5            1666.666667  100.000000

# %%
df.describe()
# Out:
#                  f1             f2            f3            f4            f5  \
# count  38040.000000   38040.000000  38040.000000  38040.000000  38040.000000
# mean       3.785699    1810.410978      2.476095      9.340598     53.460713
# std        2.369721    8549.622878      3.422023     60.371825     33.597747
# min        1.000000       2.890421      0.333333   -850.600995      0.000290
# 25%        2.000000     144.223754      0.666667     -2.401181     21.757287
# 50%        3.000000     387.890421      1.333333     -0.295001     53.173011
# 75%        5.000000    1189.452921      3.000000      6.474528     86.342162
# max       31.000000  559162.570421    103.000000   3393.505350    100.000000
#
#                  f6             f7            f8
# count  38040.000000   38040.000000  38040.000000
# mean       4.689537    9670.809971     16.157004
# std        1.855597   28707.222309     29.472355
# min        2.000000       0.223333      0.000000
# 25%        3.000000     977.612500      0.000000
# 50%        4.000000    2789.128333      0.000000
# 75%        6.000000    7857.293333     19.907828
# max       16.000000  877269.496667    100.000000

# %%
print(df.shape)
print(df.isnull().sum())
# Out:
# (38040, 8)
# f1    0
# f2    0
# f3    0
# f4    0
# f5    0
# f6    0
# f7    0
# f8    0
# dtype: int64

# %%
df.dtypes
# Out:
# f1      int64
# f2    float64
# f3    float64
# f4    float64
# f5    float64
# f6      int64
# f7    float64
# f8    float64
# dtype: object

# %% [raw]
# Все фичи - числовые, пропущенных значений нет, посмотрю на их графики.
# f3 похож на результат каких-то преобразований (1/3, 2/3, 1 1/3...).
# f1 и f6 - целочисленные, проверю сколько у них уникальных значений.

# %%
df.hist(figsize=(18,12), bins =40)
print(df.f1.nunique())
print(df.f6.nunique())
# Out:
# 29
# 15

# %% [raw]
# Cудя по гистограммам, ни один из признаков не распределен нормально, посмотрим на distplotы фичей

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))

for i, ax in enumerate(axes.flatten()):
    sns.distplot(df.iloc[:, i], ax=ax, )

# %% [raw]
# Гистограммы и плотности распределения фичей скошены, f5 распределен бимодально. Идентификация выбросов по стандартному отклонению от среднего в таком виде невозможна.
#
# Попробуем построить попарные графики, проверить есть ли заметные взаимосвязи между фичами. Несмотря на то, что, судя по количеству уникальных значений, f1 и f6 - номинативные переменные, попробую построить графики с ними и проверить,  имеют ли они выраженную связь с каким-либо признаком.
#
# f8 имеет необычное распеределение с бльшим количеством нулевых значений и медианой=0. Непонятно, действительно ли это нулевые значения или это были NAN. Являются ли нулевые значения признака нормой, а небольшое количество высоких - аномалией?
#
# f2 и f7 достигают очень высоких значений для незначительного числа юзеров. Являются ли такие значения признаков выбросами или аномалиями?

# %%
df[df.f2 > 1000]
# Out:
#            f1            f2        f3          f4          f5  f6  \
# client_id
# 1           8   3557.333333  6.000000   68.489754   79.901296   6
# 2           5  19046.793754  6.666667  103.547196    9.186530   7
# 3           3   1204.780421  0.666667    0.715220    4.637334   5
# 4           3   4413.223754  0.666667   25.565524  100.000000   2
# 5           2   1669.557088  0.333333   21.997435  100.000000   2
# ...        ..           ...       ...         ...         ...  ..
# 38162       5   1334.763754  2.666667   -8.251901   96.664566   3
# 38164       3   2513.363754  2.333333  -33.241177   74.684313   6
# 38189       5   1193.170421  5.000000  -77.019736   91.789573   3
# 38190       6   4832.393754  1.666667   -8.216552   51.029172   8
# 38192       2   4155.540421  1.333333  -46.100344   41.359751   3
#
#                       f7          f8
# client_id
# 1            5959.920000   42.304261
# 2          163662.266667    0.000000
# 3           37436.670000    0.000000
# 4            4410.333333    0.000000
# 5            1666.666667  100.000000
# ...                  ...         ...
# 38162       21410.806667   29.392830
# 38164        3361.446667    0.000000
# 38189        1200.307001    3.816189
# 38190       12186.166667   17.819731
# 38192       10040.316667  100.000000
#
# [10826 rows x 8 columns]

# %% [raw]
# Построим боксплоты и попробуем идентифицировать выбросы

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))
for i, ax in enumerate(axes.flatten()):
    sns.boxplot(y= df.iloc[:, i], orient='v' , ax=ax)
fig.tight_layout();
plt.show()

# %% [raw]
# Попробуем прологарифмировать признаки и снова построить их боксплоты. Логарифмирование позволит сохранить распределение, существенно умньшив при это размах. Возможно, в таком случае IQR будет более заметным. Так как в данных есть много нулевых значений, добавим ко всем небольшое положительное число, чтобы избежать ошибки логарифмирования.

# %%
df1 = df.copy()
for col in df1.columns:
    df1[col] = df1[col] + abs(df1[col].min())
    df1[col] = np.log1p(df1[col] + 7e-11)
    
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))
for i, ax in enumerate(axes.flatten()):
    sns.boxplot(y= df1.iloc[:, i], orient='v' , ax=ax)
fig.tight_layout();
plt.show()

# %% [raw]
# На боксплотах видно большое количество выбросов.

# %%
sns.pairplot(df)

# %% [raw]
# - визуально кажется, что признак f4 имеют ярко-выраженную линейную взаимосвязь с f2, а также менее выраженную, но все еще заметную с f7;
# - все графики с признаком f8 крайне мало информативны, f5 и f8, f6 и f8 - абсолютно неинформативны;
# - по f7 графики с f2 и f4, который уже упомянут выше, кажутся наиболее информативными, наблюдается линейная взаимосвязь, но большое количество наблюдений приходится на невысокие значения f7;
# - вид графиков с признаком f6 подтверждает теорию о том, что признак - номинативный;
# - f5 не имеет визуально заметной взаимосвязи ни с одним из признаков;
# - из графиков признака f3 и f1 нельзя сделать каких-то значительных выводов о характере их взаимосвязей с остальными фичами.
#
# проверим коэффициенты корреляции

# %%
df[['f2', 'f3', 'f4', 'f5', 'f7', 'f8']].corr()
# Out:
#           f2        f3        f4        f5        f7        f8
# f2  1.000000  0.362755  0.897123  0.061649  0.458083  0.045304
# f3  0.362755  1.000000  0.295614  0.113235  0.238927  0.017295
# f4  0.897123  0.295614  1.000000  0.042898  0.417678  0.159371
# f5  0.061649  0.113235  0.042898  1.000000 -0.179893  0.023890
# f7  0.458083  0.238927  0.417678 -0.179893  1.000000  0.073441
# f8  0.045304  0.017295  0.159371  0.023890  0.073441  1.000000

# %% [raw]
# Действительно,
# f2 и f4 - (~0.9) - имеют наибольшую положительную корреляцию
# f2 и f7 - (~0.46)
# f4 и f7 - (~0.42)
#
# Попробую построить сгруппированные по номинативному признаку графики, может быть выявятся какие-то взаимосвязи

# %%
cols = ['f2', 'f3', 'f4', 'f5', 'f7', 'f8']
plot_bars('f1', cols, df, 'sum')
print('_ count _')
plot_bars('f1', cols, df, 'count')
# Out:
# _ count _

# %% [raw]
# Из группировки по f1 признаку видно, что основная часть данных относится к определенным значениям номинативного признака f1.
# Проверю сколько наблюдений попадают в f1>16.

# %%
df[df.f1>16]
# Out:
#            f1            f2         f3          f4         f5  f6  \
# client_id
# 28         20  19366.550421  23.333333   83.024042  80.088082   6
# 252        19  13528.717088  19.000000   53.685445  17.601832  13
# 293        18  22592.717088  25.000000  141.228314  63.697046   7
# 458        19  20820.927088  18.000000   90.745376  72.294906   8
# 500        31  38072.010421  43.333333  203.762212  94.220816   4
# ...        ..           ...        ...         ...        ...  ..
# 19921      18  10251.353754  22.333333 -284.115171  28.298362   5
# 21504      25  22968.043754  21.333333 -313.719540  57.280638   3
# 22911      19  23376.527088  24.666667 -388.904941  97.023299   4
# 27803      18  32406.060421  30.666667 -651.272699  66.878868   5
# 34354      21   8685.230421  17.666667 -265.605531  71.041977   4
#
#                      f7         f8
# client_id
# 28         24503.733333   1.682596
# 252        84159.385767   0.000000
# 293        40954.426667   4.727393
# 458        31193.248720   0.000000
# 500        39221.220000  14.363769
# ...                 ...        ...
# 19921      44048.273333  13.028789
# 21504      44476.320000   2.334949
# 22911      38756.852133  46.202579
# 27803      47653.363333  16.546135
# 34354      11913.796667   0.000000
#
# [107 rows x 8 columns]

# %% [raw]
# Уникальных наблюдений совсем немного, объединю все в одно значение f1.Проверим группировку по второй номинативной переменной.

# %%
df['f1'] = df['f1'].apply(lambda x: 16 if x > 16 else x)

# %%
df
# Out:
#            f1            f2        f3          f4          f5  f6  \
# client_id
# 1           8   3557.333333  6.000000   68.489754   79.901296   6
# 2           5  19046.793754  6.666667  103.547196    9.186530   7
# 3           3   1204.780421  0.666667    0.715220    4.637334   5
# 4           3   4413.223754  0.666667   25.565524  100.000000   2
# 5           2   1669.557088  0.333333   21.997435  100.000000   2
# ...        ..           ...       ...         ...         ...  ..
# 38188       2    432.100421  0.333333   -8.118225   56.533765   4
# 38189       5   1193.170421  5.000000  -77.019736   91.789573   3
# 38190       6   4832.393754  1.666667   -8.216552   51.029172   8
# 38191       3    144.557088  1.333333   -1.776450   10.654669   5
# 38192       2   4155.540421  1.333333  -46.100344   41.359751   3
#
#                       f7          f8
# client_id
# 1            5959.920000   42.304261
# 2          163662.266667    0.000000
# 3           37436.670000    0.000000
# 4            4410.333333    0.000000
# 5            1666.666667  100.000000
# ...                  ...         ...
# 38188         759.210000    0.000000
# 38189        1200.307001    3.816189
# 38190       12186.166667   17.819731
# 38191       17727.470000    0.000000
# 38192       10040.316667  100.000000
#
# [38040 rows x 8 columns]

# %%
cols = ['f2', 'f3', 'f4', 'f5', 'f7', 'f8']
plot_bars('f6', cols, df, 'sum')
print('_ count _')
plot_bars('f6', cols, df, 'count')
# Out:
# _ count _

# %% [raw]
# По номинативному признаку f6 наблюдается схожая картина, проверим сколько уникальных значений приходится на f6>11

# %%
df[df.f6>11]
# Out:
#            f1            f2         f3         f4         f5  f6  \
# client_id
# 21          2    172.890421   0.666667   0.367084  15.354205  12
# 85          2    517.223754   0.333333   2.456793  28.994639  12
# 140         3   1136.223754   0.666667   5.590399  24.760271  12
# 252        16  13528.717088  19.000000  53.685445  17.601832  13
# 760        13  10063.593754  21.000000  73.748456  18.855388  12
# ...        ..           ...        ...        ...        ...  ..
# 35911       6    833.557088   2.000000  -6.296547  33.560444  12
# 36298       2     89.523754   0.333333  -0.132363  20.328784  13
# 37036       3    184.000421   1.000000  -8.075790   5.268040  14
# 37344       3    268.523754   1.333333  -0.366242  26.927263  13
# 37538      10   5024.610421   7.333333 -85.649674  20.234794  16
#
#                       f7         f8
# client_id
# 21           3333.788140   0.000000
# 85           3471.768280   0.000000
# 140          5537.096203   0.000000
# 252         84159.385767   0.000000
# 760         65816.591467  18.589094
# ...                  ...        ...
# 35911       56001.354133   0.000000
# 36298      325252.426667  75.521289
# 37036       24638.640000   0.000000
# 37344       59488.333333  79.274305
# 37538      546949.174333  42.335635
#
# [85 rows x 8 columns]

# %% [raw]
# Также весьма небольшое количество данных, объединю их аналогично f1.
# Цель этих преобразований в том, чтобы снизить уровень шума и упростить модели работу.

# %%
df['f6'] = df['f6'].apply(lambda x: 11 if x > 11 else x)

# %% [markdown]
# # Предобработка данных и построение моделей кластеризации

# %% [markdown]
# f2 и f7 имеют довольно высокие значения. Протестируем теорию: попробуем прологарифмировать значения этих фичей перед стандартизацией, проведем кластеризацию, проверим качество модели, а потом сделаем все то же самое на нормированных данных без предварительного логарифмирования.
#
# Для оценки работы модели будем использовать коэффициент силуэта и Davies-Bouldin index. Коэффициент силуэта равен -1 для плохой кластеризации и +1 для очень плотной кластеризации с хорошо разделенными кластерами. Коэффициент около нуля указывает на перекрывающиеся кластеры.
# Davies-Bouldin index обозначает среднее «сходство» между кластерами, где сходство является мерой, которая сравнивает расстояние между кластерами с размером самих кластеров. Ноль - это минимально возможная оценка. Значения ближе к нулю указывают на лучшее разделение.

# %% [markdown]
# ### Общий пайплайн обучения модели:
#     1.1 Выбор фичей для моделирования
#     1.2 Логарифмирование
#     1.3 Нормализация данных
#     1.4 Нахождение оптимального количества кластреров с помощью elbow метода
#     1.5 Обучение модели кластеризации K-means
#     1.6 Подсчет метрик качества
#     1.7 Визуализация

# %% [markdown]
# #### На основе пайплайна проведем серию эксперементов, чтобы построить оптимальную модель.

# %% [markdown]
# 1.1 В предположении, что номинативные переменные f1 и f6 являются числовыми, т.е. допустимо сравнение между различными значениями признака, построим первую модель с использованием этих переменных.
#
# В предположении, что переменные f1 и f6 являются категориальными и сравнение между различными значениями признака недопустимо, построим вторую модель без использования этих переменных.
# Имея дело с классификацией, можно было бы воспользоваться OneHotEncoding, но в кластеризации, где рассчитывается расстояние между признаками и центроидом пространства это было бы неправильно. В целом, для категориальных данных пространство дискретно, Евклидова функция расстояния в таком пространстве не имеет большого смысла. Как и нахождение средего между, например, значением признака "Москва" и "Новосибирск".
#
# Также пробуем осуществить нормализацию разными методами -  StandardScaler и MinmaxScaler, сравним результаты

# %% [markdown]
# #### Модель 1 со всеми признаками и нормализацией StandardScaler
# 1.2 Логарифмирование. Для логарифмирования важно, чтобы все числа были положительными.

# %%
df_log = df.copy()
df_log['f2'] = df_log['f2'] + abs(df_log['f2'].min())
df_log['f7'] = df_log['f7'] + abs(df_log['f7'].min())
df_log['f2'] = np.log(df_log.f2)
df_log['f7'] = np.log(df_log.f7)

# %% [markdown]
# 1.3 Нормализация данных с помощью StandardScaler

# %%
std_scaler = StandardScaler()
X_log_scaled = std_scaler.fit_transform(df_log)

# %% [markdown]
# 1.4 Подберем число кластеров при помощи метода "локтя". Т.к. мы будем делать это неоднократно, чтобы упростить себе задачу,
# сделаем это с помощью функции

# %%
def elbow_method(X):
    sum_of_squared_distances = []
    k_values = range(1,15)
    for k in k_values:
        km = KMeans(n_clusters=k, random_state=17)
        km = km.fit(X)
        sum_of_squared_distances.append(km.inertia_)
    
    plt.plot(k_values, sum_of_squared_distances, 'bx-')
    plt.xlabel('k')
    plt.ylabel('Sum_of_squared_distances')
    plt.title('Elbow Method For Optimal k')
    plt.show()

# %%
def clusterig_visualization(model, X):
    pca = PCA(n_components=2)
    res = pca.fit_transform(X)
    plt.figure(figsize=(12,8))
    plt.scatter(res[:,0], res[:,1], c=model.labels_, s=50, cmap='viridis')
    plt.title('PCA')

# %%
elbow_method(X_log_scaled)

# %% [markdown]
# 1.5 Обучим модель с оптимальным числом кластеров, взятых из графика выше и визуализируем кластеризацию при помощи PCA

# %%
kmeans = KMeans(n_clusters=6, random_state=17)
kmeans.fit(X_log_scaled)

clusterig_visualization(kmeans, X_log_scaled)

# %% [markdown]
# 1.6 Оценим качество модели

# %%
print('Силуэт модели, обученной на всех фичах с предобработкой данных вида log+standard_scaler и 6 кластерами: %0.3f'
      % metrics.silhouette_score(X_log_scaled, kmeans.labels_))
print('Davies-Bouldin index для этой модели: %0.3f'
      # %metrics.davies_bouldin_score(X_log_scaled, kmeans.labels_))
# Out:
# Силуэт модели, обученной на всех фичах с предобработкой данных вида log+standard_scaler и 6 кластерами: 0.218
# Соотношение между дисперсией внутри кластеров и дисперсией между кластерами для этой модели: 1.191

# %% [markdown]
# #### Модель 2 со всеми признаками и нормализацией MinMaxScaler
# 1.3 Нормализация данных

# %%
min_max_scaler = MinMaxScaler()
X_min_max_scaled = min_max_scaler.fit_transform(df)

# %% [markdown]
# 1.4 Нахождение оптимального количества кластреров с помощью elbow метода

# %%
elbow_method(X_min_max_scaled)

# %% [markdown]
# 1.5 Обучение модели кластеризации K-means с 3 кластерами

# %%
k_means = KMeans(n_clusters=3, random_state=17)
k_means.fit(X_min_max_scaled)
clusterig_visualization(k_means, X_min_max_scaled)

# %% [markdown]
# 1.6 Оценка качества модели 2

# %%
print('Силуэт модели 2, обученной на всех фичах с предобработкой данных вида min_max_scaler и 3 кластерами: %0.3f'
      % metrics.silhouette_score(X_min_max_scaled, k_means.labels_))
print('Davies-Bouldin index для этой модели: %0.3f'
      # %metrics.davies_bouldin_score(X_min_max_scaled, k_means.labels_))
# Out:
# Силуэт модели 2, обучееной на всех фичах с предобработкой данных вида min_max_scaler и 3 кластерами: 0.419
# Соотношение между дисперсией внутри кластеров и дисперсией между кластерами: 0.883

# %% [markdown]
# #### Лучших значений метрик достигает модель с предобработкой вида min_max_scaler. Дальше будем работать с ней.

# %% [markdown]
# #### Модель 3 без номинативных переменных f1 и f6 с предобработкой MinMaxScaler

# %%
df_wo_categ = df.copy()
df_wo_categ = df_wo_categ.drop(['f1', 'f6'], axis=1)

# %% [markdown]
# 1.3 Нормализация данных

# %%
X_wo_categ_min_max_scaled = min_max_scaler.fit_transform(df_wo_categ)

# %% [markdown]
# 1.4 Поиск оптимального числа кластеров

# %%
elbow_method(X_wo_categ_min_max_scaled)

# %% [markdown]
# 1.5 Обучение модели №3 с 3 кластерами и визуализация результата

# %%
kms = KMeans(n_clusters=3, random_state=17)
kms.fit(X_wo_categ_min_max_scaled)
clusterig_visualization(kms, X_wo_categ_min_max_scaled)

# %% [markdown]
# 1.6 Оценка качества модели №3

# %%
print('Силуэт модели №3 без номинативных переменных с предобработкой данных вида min_max_scaler и 3 кластерами: %0.3f'
      % metrics.silhouette_score(X_wo_categ_min_max_scaled, kms.labels_))
print('Davies-Bouldin index для этой модели: %0.3f'
      # %metrics.davies_bouldin_score(X_wo_categ_min_max_scaled, kms.labels_))
# Out:
# Силуэт модели №3 без номинативных переменных с предобработкой данных вида min_max_scaler и 3 кластерами: 0.554
# Соотношение между дисперсией внутри кластеров и дисперсией между кластерами: 0.662

# %% [markdown]
# Убрав номинативные переменные удалось улучшить показатели обеих метрик. Коэффициент силуэта модели №3 по сравнению с предыдущей моделью, обученной на всех данных вырос на 0.135 (как известно, чем выше коэффициент силуэта и ближе к 1, тем выше качество кластеризации), индекс Davies-Bouldin удалось уменьшить на 0.221 (индекс=0 соответствует максимальному качеству кластеризации).
# При этом, следует отметить, что коэффициент силуэта вычисляется существенно дольше, можно в дальнейшем оценивать качество, руководствуясь только индексом Davies-Bouldin.
# Полагаю, что такие результаты говорят о том, что верным было второе предположение о категориальном происхождения признаков f1 и f6.

# %% [raw]
# Для исследования стабильности работы модели, попробуем обучить KMeans с другим random_state, предварительно разделив данные. Сравним качество модели на этих двух выборках.

# %%
from sklearn.model_selection import train_test_split
data1, data2 = train_test_split(df_wo_categ, random_state=42, test_size=0.3)

# %%
data1_scaled = min_max_scaler.fit_transform(data1)
data2_scaled = min_max_scaler.transform(data2)

# %%
k_ms = KMeans(n_clusters=3, random_state=42)
k_ms.fit(data1_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
print('Davies-Bouldin index для этой модели: %0.3f'
      # %metrics.davies_bouldin_score(data1_scaled, k_ms.labels_))
# Out:
# Davies-Bouldin index для этой модели: 0.669

# %%
k_ms.fit(data2_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
print('Davies-Bouldin index для этой модели: %0.3f'
      # %metrics.davies_bouldin_score(data2_scaled, k_ms.labels_))
# Out:
# Davies-Bouldin index для этой модели: 0.650

# %%
Отлично, мы подобрали оптимальное количество параметров. Теперь создадим классы для пайплайна.

# %%
class LogTransformer(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None, copy=None):
        return np.log1p(X + 7e-11)
 

class Clustering(KMeans, ClusterMixin):
    
    def __init__(self, n_clusters):
        self.n_clusters = n_clusters
        
    def fit(self, X, y=None, sample_weight=None):
        self.mod = Pipeline([
            ('log', LogTransformer()),
            ('scaler', MinMaxScaler()),
            ('kmeans', KMeans(self.n_clusters, random_state=17))
        ]).fit(X)
        return self
    
    def predict(self, X):
        clusters = self.mod.predict(X).astype(str)
        return clusters

# %%
df['f4'] = df['f4'] + abs(df['f4'].min())

# %%
clust_model = Clustering(n_clusters = 2)
clust_model.fit(df)

# %%
df['cluster'] = clust_model.predict(df)

# %%
df
